# %%
import os
from roboflow import Roboflow
from ultralytics import YOLO
import supervision as sv
from dotenv import load_dotenv 
from IPython.display import display, Image, clear_output
clear_output()
load_dotenv()
# Out:
# True

# %%
ROBOFLOW_API_KEY = os.getenv('ROBOFLOW_API_KEY')

# %%
dataset_location = "./gun-and-knife-dataset"
rf = Roboflow()
project = rf.workspace("333-9gp58").project("gun-and-knife-mvzar")
dataset = project.version(3).download(
    model_format='yolov9',
    location=dataset_location
)

data_yaml_path = f"{dataset.location}/data.yaml"
print(f"Modificando el archivo: {data_yaml_path}")
# !sed -i '' '$d' {data_yaml_path}
# !sed -i '' '$d' {data_yaml_path}
# !sed -i '' '$d' {data_yaml_path}
# !sed -i '' '$d' {data_yaml_path}
# !echo -e "test: ../test/images\ntrain: ../train/images\nval: ../valid/images" >> {data_yaml_path}
# Out:
# 'project = rf.workspace("333-9gp58").project("gun-and-knife-mvzar")\ndataset = project.version(3).download(\n    model_format=\'yolov9\',\n    location=dataset_location\n)\n\ndata_yaml_path = f"{dataset.location}/data.yaml"\nprint(f"Modificando el archivo: {data_yaml_path}")\n!sed -i \'\' \'$d\' {data_yaml_path}\n!sed -i \'\' \'$d\' {data_yaml_path}\n!sed -i \'\' \'$d\' {data_yaml_path}\n!sed -i \'\' \'$d\' {data_yaml_path}\n!echo -e "test: ../test/images\ntrain: ../train/images\nval: ../valid/images" >> {data_yaml_path}\n\nprint(f"Dataset descargado y YAML modificado en: {dataset.location}")'

# %%
model = YOLO('yolov10s.yaml') 
device_to_use = 'mps' 
print(f"Iniciando entrenamiento en dispositivo: {device_to_use}")
results = model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=100,
    imgsz=640,
    optimizer="AdamW",
    augment=True,
    lr0=0.0001,
    cos_lr=True,
    workers=4,   
    batch=8,     
                 
    device=device_to_use 
)
# Out:
# Iniciando entrenamiento en dispositivo: mps
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       2 device_to_use = 'mps'
#       3 print(f"Iniciando entrenamiento en dispositivo: {device_to_use}")
#       4 results = model.train(
# ----> 5     data=f"{dataset.location}/data.yaml",
#       6     epochs=100,
#       7     imgsz=640,
#       8     optimizer="AdamW",
#       9     augment=True,
#      10     lr0=0.0001,
#      11     cos_lr=True,
#      12     workers=4,   # Bajar a 4 (u 8 si tienes muchos núcleos) es más seguro para una laptop
#      13     batch=8,     # ATENCIÓN: 'batch=40' es DEMASIADO para una laptop.
#      14                  # Emieza con 4, 8 o 16. Si da error de memoria, bájalo.
#      15     device=device_to_use
#      16 )
#      18 print("Entrenamiento completado.")
#
# NameError: name 'dataset' is not defined
