# %%
import os
from roboflow import Roboflow
from ultralytics import YOLO
import supervision as sv
from dotenv import load_dotenv 
from IPython.display import display, Image, clear_output
clear_output()
load_dotenv()
# Out:
# True

# %%
ROBOFLOW_API_KEY = os.getenv('ROBOFLOW_API_KEY')

# %%
'''dataset_location = "./gun-and-knife-dataset"
rf = Roboflow()
project = rf.workspace("333-9gp58").project("gun-and-knife-mvzar")
dataset = project.version(3).download(
    model_format='yolov9',
    location=dataset_location
)

data_yaml_path = f"{dataset.location}/data.yaml"
print(f"Modificando el archivo: {data_yaml_path}")
# !sed -i '' '$d' {data_yaml_path}
# !sed -i '' '$d' {data_yaml_path}
# !sed -i '' '$d' {data_yaml_path}
# !sed -i '' '$d' {data_yaml_path}
# !echo -e "test: ../test/images\ntrain: ../train/images\nval: ../valid/images" >> {data_yaml_path}'''
# Out:
# 'dataset_location = "./gun-and-knife-dataset"\nrf = Roboflow()\nproject = rf.workspace("333-9gp58").project("gun-and-knife-mvzar")\ndataset = project.version(3).download(\n    model_format=\'yolov9\',\n    location=dataset_location\n)\n\ndata_yaml_path = f"{dataset.location}/data.yaml"\nprint(f"Modificando el archivo: {data_yaml_path}")\n!sed -i \'\' \'$d\' {data_yaml_path}\n!sed -i \'\' \'$d\' {data_yaml_path}\n!sed -i \'\' \'$d\' {data_yaml_path}\n!sed -i \'\' \'$d\' {data_yaml_path}\n!echo -e "test: ../test/images\ntrain: ../train/images\nval: ../valid/images" >> {data_yaml_path}'

# %%
'''model = YOLO('yolov10s.yaml') 
device_to_use = 'mps' 
print(f"Iniciando entrenamiento en dispositivo: {device_to_use}")
results = model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=100,
    imgsz=640,
    optimizer="AdamW",
    augment=True,
    lr0=0.0001,
    cos_lr=True,
    workers=4,   
    batch=24,     
                 
    device=device_to_use
)'''
# Out:
# 'model = YOLO(\'yolov10s.yaml\') \ndevice_to_use = \'mps\' \nprint(f"Iniciando entrenamiento en dispositivo: {device_to_use}")\nresults = model.train(\n    data=f"{dataset.location}/data.yaml",\n    epochs=100,\n    imgsz=640,\n    optimizer="AdamW",\n    augment=True,\n    lr0=0.0001,\n    cos_lr=True,\n    workers=4,   \n    batch=24,     \n                 \n    device=device_to_use\n)'
